# %%
using   Gadfly
using   RDatasets

# %%
iris = dataset("datasets", "iris")
first(iris, 5)
# Out:
# 5×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species      │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ Categorical… │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼──────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa       │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa       │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa       │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa       │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa       │

# %%
fig1a = plot(iris, x=:SepalLength, y=:SepalWidth, color=:Species, Geom.point)
fig1b = plot(iris, x=:SepalWidth, color=:Species, Geom.density)
fig1 = hstack(fig1a, fig1b)
fig1 |> SVG(24cm, 10cm)
# Out:
# SVG(240.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=79988, maxsize=Inf, ptr=79989, mark=-1), nothing, "img-9fd732ac", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing,Property{FillOpacityPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{JSIncludePrimitive}=>nothing,Property{StrokePrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(131.02mm, 5.0mm), (219.407mm, 5.0mm), (219.407mm, 80.715mm), (131.02mm, 80.715mm)])=>"img-9fd732ac-15",ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(18.6317mm, 5.0mm), (99.4067mm, 5.0mm), (99.4067mm, 80.715mm), (18.6317mm, 80.715mm)])=>"img-9fd732ac-61"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-9fd732ac-539", false, 539, Set(AbstractString["/home/kyle/.julia/packages/Gadfly/1wgcD/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-9fd732ac-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-9fd732ac-6\")\n   .data(\"color_class\", \"color_setosa\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-7\")\n   .data(\"color_class\", \"color_versicolor\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-8\")\n   .data(\"color_class\", \"color_virginica\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-10\")\n   .data(\"color_class\", \"color_setosa\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-11\")\n   .data(\"color_class\", \"color_versicolor\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-12\")\n   .data(\"color_class\", \"color_virginica\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-16\")\n   .init_gadfly();", "fig.select(\"#img-9fd732ac-50\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-9fd732ac-52\")\n   .data(\"color_class\", \"color_setosa\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-53\")\n   .data(\"color_class\", \"color_versicolor\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-54\")\n   .data(\"color_class\", \"color_virginica\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-56\")\n   .data(\"color_class\", \"color_setosa\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-57\")\n   .data(\"color_class\", \"color_versicolor\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-58\")\n   .data(\"color_class\", \"color_virginica\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-9fd732ac-62\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((18.63166666666666mm, 5.0mm), (80.775mm, 75.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(3.895799413871703, 4.569720421111343, 4.208401172256594, -2.639440842222687, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
